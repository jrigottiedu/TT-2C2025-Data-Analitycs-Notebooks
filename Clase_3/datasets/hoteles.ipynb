# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-degarate/TT-2C2025-Data-Analitycs-Notebooks/blob/main/Clase_3/datasets/hoteles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lee los archivos subidos a la carpeta virtual de trabajo
# Hay que abrir el indice de archivos en el panel de la izq
# y luego subir el archivo manualmente

# Importar la librería Pandas
import pandas as pd


# Usar el método read_csv de Pandas (pd) que recibe como argumento el archivo csv y retorna un dataframe
df1 = pd.read_csv("users.csv")
df1.head()
print(f"Number of rowsof df1: {len(df1)}")

# %%
# Usar el método read_csv de Pandas (pd) que recibe como argumento el archivo csv y retorna un dataframe
df2 = pd.read_csv("hotels.csv")
df2.head()

# %%
# Usar el método read_csv de Pandas (pd) que recibe como argumento el archivo csv y retorna un dataframe
df3 = pd.read_csv("reviews.csv")

'''
Using len(df.index)
This method explicitly gets the length of the DataFrame's index, which directly
corresponds to the number of rows. This is often considered the most explicit
and sometimes the fastest method for large DataFrames.
'''
num_rows = len(df3.index)
print(f"Number of rows: {num_rows}")

df3.head()
# Out:
# Number of rows: 50000
#    review_id  user_id  hotel_id review_date  score_overall  score_cleanliness  \
# 0          1     1600         1  2022-10-07            8.7                8.6
# 1          2      432         4  2020-03-24            9.1               10.0
# 2          3      186        18  2023-12-18            8.8                9.7
# 3          4     1403        19  2022-06-22            8.9                9.0
# 4          5     1723        17  2022-07-02            9.1                8.9
#
#    score_comfort  score_facilities  score_location  score_staff  \
# 0            8.7               8.5             9.0          8.8
# 1            9.1               9.0             8.6          9.4
# 2            8.8               8.3             8.7          8.1
# 3            8.8               8.5             9.6          9.1
# 4            9.5               9.3             8.3          9.4
#
#    score_value_for_money                                        review_text
# ...

# %%
# Verificar que los archivos csv se encuentren en la carpeta datasets
import os
os.listdir("/content/drive/MyDrive/datasets")

# %%
# Lee los archivos dentro de una carpeta de Google drive
# Path to the CSV file in Google Drive
file_path = "/content/drive/MyDrive/Colab Notebooks/CDATOS/Clase03/datasets/"

# Read the CSV file into a pandas DataFrame
df4 = pd.read_csv(file_path + "hotels.csv")

# Display the first few rows of the DataFrame
display(df4.head())

num_rows = df4.shape[0]
print(f"Number of rows: {num_rows}")

# %%
# Liberar la unidad
# drive.flush_and_unmount()

# %%
# Carga archivos locales a la carpeta virtual de trabajo
from google.colab import files

uploaded = files.upload()

# %% [markdown]
# CARGAR .csv DESDE GITHUB

# %%
# Cargar en una variable la URL del archivo csv de Github
url = "https://github.com/alex-degarate/TT-2C2025-Data-Analitycs-Notebooks/raw/refs/heads/main/Clase_3/Datasets/hotels.csv"

import pandas as pd

# Usar el método read_csv de Pandas (pd) que recibe como argumento el archivo csv
# y retorna un dataframe
df_github = pd.read_csv(url)
df_github.head()


# print(f"Number of rows of df_github: {len(df_github)}")
# Out:
# Number of rows of df_github: 25

# %% [markdown]
# CARGAR una planilla de calculo desde GITHUB

# %%
# Cargar en una variable la URL del archivo xlsx de Github
url = "https://github.com/alex-degarate/TT-2C2025-Data-Analitycs-Notebooks/raw/refs/heads/main/Clase_3/Datasets/Kaggle_users.xlsx"
#url = "Kaggle_users.xlsx"

import pandas as pd

df_calc = pd.read_excel(url)

print(f"Number of rows of df_calc: {len(df_calc)}")

df_calc.head()

#
# Out:
# Number of rows of df_calc: 2000
#    user_id user_gender         country age_group traveller_type  join_date
# 0        1      Female  United Kingdom     35-44           Solo 2024-09-29
# 1        2        Male  United Kingdom     25-34           Solo 2023-11-29
# 2        3      Female          Mexico     25-34         Family 2022-04-03
# 3        4        Male           India     35-44         Family 2023-12-02
# 4        5       Other           Japan     25-34           Solo 2021-12-18
